# %%
import transformer
import torch
import importlib

importlib.reload(transformer)
# Out:
# <module 'transformer' from '/Users/desktop/Documents/a-slm/transformer.py'>

# %%
torch.manual_seed(42)

# %%
attention = transformer.GroupedQueryAttention(
    hidden_size = 32,
    num_q_heads = 4,
    num_kv_heads = 2,
    window_size = 3,
)


inputs = torch.randn(2, 8, 32)

out = attention(inputs)


print(inputs.shape)
print(out.shape)
